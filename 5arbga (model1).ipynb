# %%
#this function store the possible moves for each rock
def possible_moves(i,j):
    from collections import defaultdict
    d=defaultdict(list)
    if(i==0 and j==0):
        d[0].append(0)
        d[0].append(1)
        d[1].append(1)
        d[1].append(0)
        d[2].append(1)
        d[2].append(1)
    elif(i==0 and j==2):
        d[0].append(0)
        d[0].append(1)
        d[1].append(1)
        d[1].append(2)
        d[2].append(1)
        d[2].append(1)
    elif(i==2 and j==0):
        d[0].append(1)
        d[0].append(0)
        d[1].append(2)
        d[1].append(1)
        d[2].append(1)
        d[2].append(1)
    elif(i==2 and j==2):
        d[0].append(1)
        d[0].append(2)
        d[1].append(2)
        d[1].append(1)
        d[2].append(1)
        d[2].append(1)
    elif(i==0 and j==1):
        d[0].append(0)
        d[0].append(0)
        d[1].append(0)
        d[1].append(2)
        d[2].append(1)
        d[2].append(1)
    elif(i==2 and j==1):
        d[0].append(2)
        d[0].append(0)
        d[1].append(2)
        d[1].append(2)
        d[2].append(1)
        d[2].append(1)
    elif(i==1 and j==0):
        d[0].append(0)
        d[0].append(0)
        d[1].append(2)
        d[1].append(0)
        d[2].append(1)
        d[2].append(1)
    elif(i==1 and j==2):
        d[0].append(0)
        d[0].append(2)
        d[1].append(2)
        d[1].append(2)
        d[2].append(1)
        d[2].append(1)
    return d

# %%
# if we have 3 rocks in the same line that mean the game is over 
# The value -10 means that the player beat the computer 
# The value 10 means that the player lost to the computer 
def evaluate(b,pc,op) :
   
    for row in range(3) :    
        if (b[row][0] == b[row][1] and b[row][1] == b[row][2]) :       
            if (b[row][0] == pc) :
                return 10
            elif (b[row][0] == op) :
                return -10
 
   
    for col in range(3) :
      
        if (b[0][col] == b[1][col] and b[1][col] == b[2][col]) :
         
            if (b[0][col] == pc) :
                return 10
            elif (b[0][col] == op) :
                return -10
 
    if (b[0][0] == b[1][1] and b[1][1] == b[2][2]) :
     
        if (b[0][0] == pc) :
            return 10
        elif (b[0][0] == op) :
            return -10
 
    if (b[0][2] == b[1][1] and b[1][1] == b[2][0]) :
     
        if (b[0][2] == pc) :
            return 10
        elif (b[0][2] == op) :
            return -10
 
   
    return 0

# %%
def minimax(damma, depth, Max,alpha,beta,pc,op):

    score = evaluate(damma,pc,op)

    if (score == 10):
        return score,depth

    if (score == -10):
          
        return score,depth
    # the limit depth 
    if (depth == 7):
        return 0,depth

    if (Max):
        dep=10
        best = -1000
        for i in range(2,-1,-1):
        
            for j in range(2,-1,-1):
            
                
                if (damma[i][j]==pc and ((i==1) and (j==1))==False):
                    v=possible_moves(i,j)
                    for x in range(3):

                        y=v[x][0]
                        z=v[x][1]
                        if (damma[y][z]=='_'):
                            damma[i][j] = '_'
                            damma[y][z] = pc
                            val_best,val_dep=minimax(damma, depth+1,not(Max),alpha,beta,pc,op)
                        
                            if(best==val_best):
                                    dep=min(dep,val_dep)
                            elif(best<val_best):
                                    dep=val_dep
                            best = max(best,val_best)
                            alpha = max(alpha, best)
                        

                            damma[i][j] = pc
                            damma[y][z] = '_'
                        

                
                elif(damma[i][j]==pc and ((i==1) and (j==1))==True):
                    for s in range(3):
        
                        for k in range(3):
            
                          if (damma[s][k]=='_' and ((s==1) and (k==1))==False):
                                damma[1][1] = '_'
                                damma[s][k] = pc
                                val_best,val_dep=minimax(damma, depth+1,not(Max),alpha,beta,pc,op)
                              
                                if(best==val_best):
                                    dep=min(dep,val_dep)
                                elif(best<val_best):
                                     dep=val_dep
                                best = max(best,val_best)
                                alpha = max(alpha,best)
                                damma[1][1] = pc
                                damma[s][k] = '_'
                        
       

                
            
        
        return best,dep
        
    

   
    else:
    
        best = 1000
        dep=10
      
        for i in range(2,-1,-1):
        
            for j in range(2,-1,-1):
            
               
                if (damma[i][j]==op and ((i==1) and (j==1))==False):
                    v=possible_moves(i,j)
                    for x in range(3):
                        y=v[x][0]
                        z=v[x][1]
                       
                        if (damma[y][z]=='_'):
                            damma[i][j] = '_'
                            damma[y][z] =op
                            
                            val_best,val_dep=minimax(damma, depth+1,not(Max),alpha,beta,pc,op)
                         
                            if(best==val_best):
                                    dep=min(dep,val_dep)
                            elif(best>val_best):
                                    dep=val_dep                           

                            best = min(best,val_best)
                            beta = min(beta,best)
                   
                            damma[i][j] = op
                            damma[y][z] = '_'
                         
                
                elif (damma[i][j]==op and ((i==1) and (j==1))==True):
                    for s in range(3):
        
                       for k in range(3):
            
                            if (damma[s][k]=='_' and ((s==1) and (k==1))==False):
                                damma[1][1] = '_'
                                damma[s][k] = op
                                val_best,val_dep=minimax(damma, depth+1,not(Max),alpha,beta,pc,op)
                               
                                if(best==val_best):
                                    dep=min(dep,val_dep)
                                elif(best>val_best):
                                    dep=val_dep
                                else:
                                    dep=dep
                            
                                best = min(best,val_best)
                                beta = min(beta,best)
                                damma[1][1] = op
                                damma[s][k] = '_'
                                                            

        return best,dep

# %%
def findBestMove(damma,pc,op):

    bestVal = -1000
    bestdepth=1000
    bestMove_rowy = -1
    bestMove_colz = -1
    bestMove_rowi = -1
    bestMove_colj = -1
    

   
    for i in range(3):
    
        for j in range(3):
        
           
            if ((damma[i][j]==pc) and ((i==1) and (j==1))==False):
                v = possible_moves(i,j)
                for x in range(3):

                    y=v[x][0]
                    z=v[x][1]
                    if (damma[y][z]=='_'):
                        damma[i][j] = '_'
                        damma[y][z] = pc
                        moveVal_best,moveVal_dep = minimax(damma, 0, False,-1000,1000,pc,op)
                        print("moveVal_best   ",moveVal_best)
                        print("moveVal_dep   ",moveVal_dep)
                        damma[i][j] = pc
                        damma[y][z] = '_'
                        print("  ")
                        print(i,"   ",j)
                        print(y,"   ",z)
                        print("  ")

                        if((moveVal_best==10) and (moveVal_dep < bestdepth)):
                                bestMove_rowy = y
                           
                                bestMove_colz = z
                           
                                bestMove_rowi = i
                            
                                bestMove_colj = j
                                
                                bestVal = moveVal_best
                                print("bestVal   ",bestVal)
                                bestdepth=moveVal_dep
                                print("bestdepth   ",bestdepth)
                    

                
                        if (moveVal_best > bestVal ):
                                bestMove_rowy = y
                            
                                bestMove_colz = z
                           
                                bestMove_rowi = i
                            
                                bestMove_colj = j
                            
                                bestVal = moveVal_best
                                print("bestVal   ",bestVal)
                print("*************")     
                

            elif(damma[i][j]==pc and ((i==1) and(j==1))==True):
                for i1 in range(3):
        
                      for j1 in range(3):
            
                           if(damma[i1][j1]=='_'and ((i1==1) and (j1==1))==False):
                            damma[1][1] = '_'
                            damma[i1][j1] = pc
                            moveVal_best,moveVal_dep = minimax(damma, 0, False,-1000,1000,pc,op)
                            print("moveVal_best   ",moveVal_best)
                            print("moveVal_dep   ",moveVal_dep)
                            damma[1][1] = pc
                            damma[i1][j1] ='_'
                            print("1","   ","1")
                            print(i1,"   ",j1)
                            
                            if(moveVal_best==10 and (moveVal_dep < bestdepth)):
                                    bestMove_rowy = i1
                                    
                                    bestMove_colz = j1
                                   
                                    bestMove_rowi = 1
                                    
                                    bestMove_colj = 1
                                   
                                    bestVal = moveVal_best
                                    print("bestVal   ",bestVal)
                                    bestdepth=moveVal_dep
                                    print("bestdepth   ",bestdepth)

                                    
                
                            if (moveVal_best > bestVal ):
                                    bestMove_rowy = i1
                                    
                                    bestMove_colz = j1
                                    
                                    bestMove_rowi = 1
                                    
                                    bestMove_colj = 1
                                    
                                    bestVal = moveVal_best
                                    print("bestVal   ",bestVal)
                print("*************")    
    print("The value of the best Move is : ",bestVal)

    return  bestMove_rowy ,bestMove_colz ,bestMove_rowi ,bestMove_colj ,bestdepth,bestVal

# %%
def damma(p,o):
    pc=p
    op=o
    damma = [
        ['x', '_', 'x'],
        ['x', 'o', 'o'],              
        ['o', '_', '_']
         ]
    bestMove_rowy ,bestMove_colz ,bestMove_rowi ,bestMove_colj,d,b = findBestMove(damma,op,pc)
 
    print("move the x from the position  :")
    print("ROW : ",bestMove_rowi, "COL :",bestMove_colj)
    print("to  :")
    print("ROW : ",bestMove_rowy, "COL :",bestMove_colz)
    print(d)
    print(b)

# %%
damma('x','o')
# Out:
# moveVal_best    0
# moveVal_dep    5
# 1     1
# 0     1
# bestVal    0
# moveVal_best    10
# moveVal_dep    2
# 1     1
# 2     1
# bestVal    10
# bestdepth    2
# moveVal_best    -10
# moveVal_dep    3
# 1     1
# 2     2
# *************
# moveVal_best    10
# moveVal_dep    2
#
# 1     2
# 2     2
#
# *************
# moveVal_best    0
# moveVal_dep    5
#
# 2     0
# 2     1
#
# *************
# The value of the best Move is :  10
# move the x from the position  :
# ROW :  1 COL : 1
# to  :
# ROW :  2 COL : 1
# 2
# 10

# %%
def placed(board,i,j,count,pc,op,l1):
    
    if(count==1):  
        if(board[1][1]=='_'):
            board[1][1]=pc
            return board,1,1,l1
        else:
            if([i,j] in l1 ):
                l1.remove([i,j])
            board[l1[0][0]][l1[0][1]]=pc
            s=l1[0]
            l1.remove(l1[0])
            return board,s[0],s[1],l1
    elif(count==2):
        for i in range(3):
            for j in range(3):
                if(board[i][j]=='_'):
                    board[i][j]=op
                    if evaluate(board,pc,op)==-10:
                        board[i][j]=pc
                        return board,i,j,l1
                    else:
                        board[i][j]='_'
        if([i,j] in l1 ):
                l1.remove([i,j])
        board[l1[0][0]][l1[0][1]]=pc
        return board ,l1[0][0],l1[0][1] ,l1       
        
                        
                    
    else:
        for i in range(3):
            for j in range(3):
                if(board[i][j]=='_'):
                    board[i][j]=pc
                    if evaluate(board,pc,op)==10:
                        return board,i,j,l1
                    else:
                        board[i][j]='_'
                    
        for i in range(3):
            for j in range(3):
                if(board[i][j]=='_'):
                    board[i][j]=pc
                    y,z,i1,j2,d,b = findBestMove(board,op,pc)
                    if(d==0 and b==10):
                        board[i][j]='_'
                        board[y][z]=pc
                        print("ksdfdkfd,,dfgk")
                        return board,y,z,l1
                    elif(d==1 and b==10):
                        board[i][j]='_'
                        board[y][z]=pc
                        return board,y,z,l1
                    elif(d<=3 and b==10):
                        board[i][j]='_'
                        board[y][z]=pc
                        return board,y,z,l1
                    else:
                        board[i][j]='_'

# %%
from tkinter import *
bigBoxSize = 150

class cFrame(Frame):
    def __init__(self, master, cwidth=450, cheight=450):
        Frame.__init__(self, master, relief=RAISED, height=550, width=600, bg = "grey")
        self.canvasWidth = cwidth
        self.canvasHeight = cheight
        self.canvas = Canvas(self, bg="white", width=cwidth, height=cheight, border =0)
        self.drawGridLines()
        self.canvas.pack(side=TOP, pady=20, padx=20)

        
    def drawGridLines(self, linewidth = 10):
        self.canvas.create_line(0, 5, self.canvasWidth, 5, width= linewidth )
        self.canvas.create_line(5, 0, 5, self.canvasHeight, width= linewidth )
        self.canvas.create_line(450, 450, 0, 0, width= linewidth )
        self.canvas.create_line(450, 450, 0, 0, width= linewidth )
        self.canvas.create_line(450, 0, 0, 450, width= linewidth )
        self.canvas.create_line(225, 0, 225, 450, width= linewidth )
        self.canvas.create_line(0, self.canvasHeight, self.canvasWidth + 2, self.canvasHeight, width= linewidth )
        self.canvas.create_line(self.canvasWidth, self.canvasHeight, self.canvasWidth, 1, width= linewidth )
        self.canvas.create_line(0,225, 450, 225, width= linewidth )
        
        self.bc00 = Button(self.canvas,text="",bg='white', fg='black',command=lambda:arbgaa(self.bc00))
        self.bc00.place(relx=0,rely=0, relwidth=0.05,relheight=0.05)
        
        self.bc02 = Button(self.canvas,text="",bg='white', fg='black',command=lambda:arbgaa(self.bc02))
        self.bc02.place(relx=0.95,rely=0, relwidth=0.05,relheight=0.05)

        self.bc20 = Button(self.canvas,text="",bg='white', fg='black',command=lambda:arbgaa(self.bc20))
        self.bc20.place(relx=0,rely=0.95, relwidth=0.05,relheight=0.05)

        self.bc22 = Button(self.canvas,text="",bg='white', fg='black',command=lambda:arbgaa(self.bc22))
        self.bc22.place(relx=0.95,rely=0.95, relwidth=0.05,relheight=0.05)
        
        self.b01 = Button(self.canvas,text="",bg='white', fg='black',command=lambda:arbgaa(self.b01))
        self.b01.place(relx=0.47,rely=0, relwidth=0.05,relheight=0.05)
        
        self.b21 = Button(self.canvas,text="",bg='white', fg='black',command=lambda:arbgaa(self.b21))
        self.b21.place(relx=0.47,rely=0.95, relwidth=0.05,relheight=0.05)
        
        self.b10 = Button(self.canvas,text="",bg='white', fg='black',command=lambda:arbgaa(self.b10))
        self.b10.place(relx=0,rely=0.47, relwidth=0.05,relheight=0.05)
        
        self.b12 = Button(self.canvas,text="",bg='white', fg='black',command=lambda:arbgaa(self.b12))
        self.b12.place(relx=0.95,rely=0.47, relwidth=0.05,relheight=0.05)
        
        self.b11 = Button(self.canvas,text="",bg='white', fg='black',command=lambda:arbgaa(self.b11))
        self.b11.place(relx=0.47,rely=0.47, relwidth=0.05,relheight=0.05)
       
        self.bf = [
          [ self.bc00, self.b01, self.bc02 ],
          [ self.b10, self.b11, self.b12 ],
          [ self.bc20, self.b21, self.bc22 ]
              ]
        self.arbga = [
             [ '_', '_', '_' ],
             [ '_', '_', '_' ],
             [ '_', '_', '_' ]
                ]

        self.count=0
        self.l=[[0,1],[1,0],[1,2],[2,1]]
        def game(board,pc,op,c):
            
            if(c.cget('bg')=='white'):
                c.configure(bg = "red") 
            movei=0
            movej=0
            for i in range(3):
                for j in range(3):
                    if self.bf[i][j]==c :
                        movei=i
                        movej=j
               
            if([movei,movej] in self.l):
                self.l.remove([movei,movej])        
            if(board[movei][movej] == '_'):
                        board[movei][movej] = op
                        self.count += 1
                        print(self.count)
            board,y,z,self.l=placed(board,movei,movej,self.count,pc,op,self.l)
            print(y,z)
            
            self.bf[y][z].configure(bg="blue")
            
            print(board[0])
            print(board[1])
            print(board[2])        
            return board
        def arbgaa(c):
            
            if(self.count<3):
                self.arbga=game(self.arbga,'x','o',c)
            else:    
         
                print("It's your turn," + 'op'+ ".Move to which place?")
                if(c.cget('bg')=='red'):
                    c.configure(bg = "white") 
                    movei=0
                    movej=0
                    for i in range(3):
                        for j in range(3):
                            if self.bf[i][j]==c :
                                movei=i
                                movej=j
                                self.arbga[movei][movej] = '_'
                                print(self.arbga)
       
                          
                else:
                    c.configure(bg = "red")
                    movey=0
                    movez=0
                    for i in range(3):
                        for j in range(3):
                            if self.bf[i][j]==c :
                                movey=i
                                movez=j           
                    if(self.arbga[movey][movez] == '_'):
                        self.arbga[movey][movez] = 'o'
                    y,z ,i,j,d,b  = findBestMove(self.arbga,'x','o')
                    self.arbga[i][j]='_'
                    self.arbga[y][z]='x'
                    self.bf[i][j].configure(bg="white")
                    self.bf[y][z].configure(bg="blue")
                    print(self.arbga[0])
                    print(self.arbga[1])
                    print(self.arbga[2])

        self.testb=False
        def color_change(c):
            if(c.cget('bg')=='white'):
                c.configure(bg = "red")  
            else:
                c.configure(bg = "white")  
       
        

       
    

root = Tk()
C = cFrame(root)
C.pack()
root.mainloop()
# Out:
# 1
# 0 1
# ['_', 'x', '_']
# ['_', 'o', '_']
# ['_', '_', '_']
